# %% [markdown]
# <a href="https://colab.research.google.com/github/Shafna81/fakenewsdetection/blob/main/Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/jibranfawaid/turnbackhoax-dataset.git
# Out:
# fatal: destination path 'turnbackhoax-dataset' already exists and is not an empty directory.

# %%
# !git clone https://github.com/pierobeat/Hoax-News-Classification
# Out:
# fatal: destination path 'Hoax-News-Classification' already exists and is not an empty directory.

# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %%
# !pip install Sastrawi
import re
import pandas as pd
import numpy as np
import random
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
# Load the "Fix" sheet of the Excel file into a pandas DataFrame
df = pd.read_excel('turnbackhoax-dataset/Meta Data.xlsx', sheet_name='Fix')

# Print the first few rows of the DataFrame to verify that it loaded correctly
df.head()
# Out:
#    Label                                           Headline  \
# 0      1  Pertamina dan Pemerintah Kalrifikasi Isu BBM N...
# 1      1  Polda Nusa Tenggara Barat Mengklarifkasi Bahwa...
# 2      1  PT Ultrajaya Milk Industry Tbk Mengklarifikasi...
# 3      1  BBKSDA Jatim Mengklarifikasi Bahwa Wisata Alam...
# 4      1  BMKG Mataram Menghimbau Agar Warga Tidak Langs...
#
#                                                 Body
# 0  Foto: Kumparan.com Debunk ini berisi iKlarifik...
# 1  Foto Ilustrasi Perkosaan Debunk ini berisi kla...
# 2  Debunk ini berisi klarifikasi dari PT Ultrajay...
# 3  foto: tribunnews.com Debunk ini berisi Klrifik...
# 4  Foto: tribunnews.com (Jokowi sedang memantau l...

# %%
df["Text"] = df["Headline"] + " " + df["Body"]

# %%
df3 = pd.read_csv('Hoax-News-Classification/data/500_berita_indonesia.csv', sep=";")
df3.head()
# Out:
#   kategori                                             berita
# 0    valid  "Gunung Agung erupsi untuk pertama kali pada 2...
# 1    valid  "Jakarta, CNN Indonesia -- Menteri BUMN Erick ...
# 2    valid  "Dosen Fakultas Kedokteran Hewan IPB, Yusuf Ri...
# 3    valid  "Jakarta - Dua anggota TNI, Serda N dan Serda ...
# 4    valid  "Akui Tembak Jatuh Pesawat Ukraina, Iran Tuai ...

# %%
df3["Label"] = df3["kategori"].replace("valid", 1).replace("hoax",0)
df3["Text"] = df3["berita"]
df3
# Out:
#     kategori                                             berita  Label  \
# 0      valid  "Gunung Agung erupsi untuk pertama kali pada 2...      1
# 1      valid  "Jakarta, CNN Indonesia -- Menteri BUMN Erick ...      1
# 2      valid  "Dosen Fakultas Kedokteran Hewan IPB, Yusuf Ri...      1
# 3      valid  "Jakarta - Dua anggota TNI, Serda N dan Serda ...      1
# 4      valid  "Akui Tembak Jatuh Pesawat Ukraina, Iran Tuai ...      1
# ..       ...                                                ...    ...
# 495     hoax  "AA Gym : Lebih baik pilih pemimpin koruptor t...      0
# 496     hoax  "Sebuah gambar dengan keterangan “Sultan Erdog...      0
# 497     hoax  "Restoran Padang "Sederhana" sedang merayakan ...      0
# 498     hoax  "Ini adalah binatang yang langka dan sangat be...      0
# 499     hoax  "Mohon ijin sekedar info, menginformasikan bah...      0
#
#                                                   Text
# 0    "Gunung Agung erupsi untuk pertama kali pada 2...
# ...

# %%
df3 = df3.drop(columns=['kategori', 'berita'])

# %%
df3
# Out:
#      Label                                               Text
# 0        1  "Gunung Agung erupsi untuk pertama kali pada 2...
# 1        1  "Jakarta, CNN Indonesia -- Menteri BUMN Erick ...
# 2        1  "Dosen Fakultas Kedokteran Hewan IPB, Yusuf Ri...
# 3        1  "Jakarta - Dua anggota TNI, Serda N dan Serda ...
# 4        1  "Akui Tembak Jatuh Pesawat Ukraina, Iran Tuai ...
# ..     ...                                                ...
# 495      0  "AA Gym : Lebih baik pilih pemimpin koruptor t...
# 496      0  "Sebuah gambar dengan keterangan “Sultan Erdog...
# 497      0  "Restoran Padang "Sederhana" sedang merayakan ...
# 498      0  "Ini adalah binatang yang langka dan sangat be...
# 499      0  "Mohon ijin sekedar info, menginformasikan bah...
#
# [500 rows x 2 columns]

# %%
df4 = pd.read_csv('drive/MyDrive/Colab Notebooks/SKRIPSI/datasetmendeley.csv', sep=";", encoding='iso-8859-1')
df4.head()
# Out:
#                                               berita tagging
# 0  Jakarta, Di jejaring sosial, banyak beredar in...   Valid
# 1  Isu bahwa ikan lele mengandung sel kanker di j...   Valid
# 2  Bagi penikmat kuliner dengan bahan dasar ikan ...   Valid
# 3  Ikan lele merupakan salah satu makanan favorit...   Valid
# 4  Ikan lele merupakan bahan makanan yang cukup p...   Valid

# %%
df4["Label"] = df4["tagging"].replace("Valid", 1).replace("Hoax",0)
df4["Text"] = df4["berita"]
df4
# Out:
#                                                 berita tagging  Label  \
# 0    Jakarta, Di jejaring sosial, banyak beredar in...   Valid      1
# 1    Isu bahwa ikan lele mengandung sel kanker di j...   Valid      1
# 2    Bagi penikmat kuliner dengan bahan dasar ikan ...   Valid      1
# 3    Ikan lele merupakan salah satu makanan favorit...   Valid      1
# 4    Ikan lele merupakan bahan makanan yang cukup p...   Valid      1
# ..                                                 ...     ...    ...
# 595  Kabar yang beredar seputar rencana kenaikan ga...   Valid      1
# 596  Kabar yang beredar seputar rencana kenaikan ga...   Valid      1
# 597  Akhir-akhir ini, beredar pemberitaan yang meny...   Valid      1
# 598  Rancangan peraturan pemerintah (RPP) tentang G...   Valid      1
# 599  Kabar yang beredar seputar rencana kenaikan ga...   Valid      1
#
#                                                   Text
# 0    Jakarta, Di jejaring sosial, banyak beredar in...
# ...

# %%
df4 = df4.drop(columns=['tagging', 'berita'])

# %%
df4
# Out:
#      Label                                               Text
# 0        1  Jakarta, Di jejaring sosial, banyak beredar in...
# 1        1  Isu bahwa ikan lele mengandung sel kanker di j...
# 2        1  Bagi penikmat kuliner dengan bahan dasar ikan ...
# 3        1  Ikan lele merupakan salah satu makanan favorit...
# 4        1  Ikan lele merupakan bahan makanan yang cukup p...
# ..     ...                                                ...
# 595      1  Kabar yang beredar seputar rencana kenaikan ga...
# 596      1  Kabar yang beredar seputar rencana kenaikan ga...
# 597      1  Akhir-akhir ini, beredar pemberitaan yang meny...
# 598      1  Rancangan peraturan pemerintah (RPP) tentang G...
# 599      1  Kabar yang beredar seputar rencana kenaikan ga...
#
# [600 rows x 2 columns]

# %%
def preprocessing(text):
    # case folding
    text = text.lower()

    # remove punctuation and non-alphabetic characters
    text = re.sub(r'[^\w\s]', '', text)

    # remove numbers
    text = re.sub(r'\d+', '', text)

    # stopword removal
    factory = StopWordRemoverFactory()
    stopwords = factory.get_stop_words()
    words = text.split()
    text = " ".join([word for word in words if word not in stopwords])

    return text

# %%
df.head()
# Out:
#    Label                                           Headline  \
# 0      1  Pertamina dan Pemerintah Kalrifikasi Isu BBM N...
# 1      1  Polda Nusa Tenggara Barat Mengklarifkasi Bahwa...
# 2      1  PT Ultrajaya Milk Industry Tbk Mengklarifikasi...
# 3      1  BBKSDA Jatim Mengklarifikasi Bahwa Wisata Alam...
# 4      1  BMKG Mataram Menghimbau Agar Warga Tidak Langs...
#
#                                                 Body  \
# 0  Foto: Kumparan.com Debunk ini berisi iKlarifik...
# 1  Foto Ilustrasi Perkosaan Debunk ini berisi kla...
# 2  Debunk ini berisi klarifikasi dari PT Ultrajay...
# 3  foto: tribunnews.com Debunk ini berisi Klrifik...
# 4  Foto: tribunnews.com (Jokowi sedang memantau l...
#
#                                                 Text
# 0  Pertamina dan Pemerintah Kalrifikasi Isu BBM N...
# 1  Polda Nusa Tenggara Barat Mengklarifkasi Bahwa...
# 2  PT Ultrajaya Milk Industry Tbk Mengklarifikasi...
# 3  BBKSDA Jatim Mengklarifikasi Bahwa Wisata Alam...
# ...

# %%
df = df.drop(columns=['Headline', 'Body'])

# %%
if not os.path.exists('drive/MyDrive/Colab Notebooks/SKRIPSI'):
   os.makedirs('drive/MyDrive/Colab Notebooks/SKRIPSI')

# %%
combined_df = pd.concat([df, df3, df4], ignore_index=True)
combined_df
# Out:
#       Label                                               Text
# 0         1  Pertamina dan Pemerintah Kalrifikasi Isu BBM N...
# 1         1  Polda Nusa Tenggara Barat Mengklarifkasi Bahwa...
# 2         1  PT Ultrajaya Milk Industry Tbk Mengklarifikasi...
# 3         1  BBKSDA Jatim Mengklarifikasi Bahwa Wisata Alam...
# 4         1  BMKG Mataram Menghimbau Agar Warga Tidak Langs...
# ...     ...                                                ...
# 2211      1  Kabar yang beredar seputar rencana kenaikan ga...
# 2212      1  Kabar yang beredar seputar rencana kenaikan ga...
# 2213      1  Akhir-akhir ini, beredar pemberitaan yang meny...
# 2214      1  Rancangan peraturan pemerintah (RPP) tentang G...
# 2215      1  Kabar yang beredar seputar rencana kenaikan ga...
#
# [2216 rows x 2 columns]

# %%
combined_df["Text"] = combined_df["Text"].apply(preprocessing)
combined_df
# Out:
#       Label                                               Text
# 0         1  pertamina pemerintah kalrifikasi isu bbm naik ...
# 1         1  polda nusa tenggara barat mengklarifkasi kejad...
# 2         1  pt ultrajaya milk industry tbk mengklarifikasi...
# 3         1  bbksda jatim mengklarifikasi wisata alam kawah...
# 4         1  bmkg mataram menghimbau warga langsung percaya...
# ...     ...                                                ...
# 2211      1  kabar beredar seputar rencana kenaikan gaji pr...
# 2212      1  kabar beredar seputar rencana kenaikan gaji pr...
# 2213      1  akhirakhir beredar pemberitaan menyatakan kena...
# 2214      1  rancangan peraturan pemerintah rpp gaji tunjan...
# 2215      1  kabar beredar seputar rencana kenaikan gaji pr...
#
# [2216 rows x 2 columns]

# %%
combined_df.to_csv('drive/MyDrive/Colab Notebooks/SKRIPSI/dataset.csv', index=False)

# %%
df2 = pd.read_csv('drive/MyDrive/Colab Notebooks/SKRIPSI/dataset.csv')

# %%
df2.head()
# Out:
#    Label                                               Text
# 0      1  pertamina pemerintah kalrifikasi isu bbm naik ...
# 1      1  polda nusa tenggara barat mengklarifkasi kejad...
# 2      1  pt ultrajaya milk industry tbk mengklarifikasi...
# 3      1  bbksda jatim mengklarifikasi wisata alam kawah...
# 4      1  bmkg mataram menghimbau warga langsung percaya...
